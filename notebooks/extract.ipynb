# %%
import pandas as pd

# %%
df_heartrate = pd.read_csv("../data/raw/heart_rate_zones.csv")
df_heartrate.head()
# Out:
#    zone  min_percentage  max_percentage        label
# 0     1              50              60     Recovery
# 1     2              60              70     Fat Burn
# 2     3              70              80       Cardio
# 3     4              80              90  Performance
# 4     5              90             100      Maximum

# %%
df_exercise_metadata = pd.read_csv("../data/raw/exercise_metadata.csv")
df_exercise_metadata
# Out:
#       exercise muscle_group intensity_level
# 0  Bench Press        Chest          Medium
# 1        Squat         Legs            High
# 2     Deadlift         Back            High
# 3      Running    Full Body          Medium
# 4      Cycling         Legs          Medium
# 5         Yoga     Mobility             Low
# 6         HIIT    Full Body       Very High
# 7       Rowing         Back          Medium

# %%
df_user_metadata = pd.read_csv("../data/raw/users_metadata_messy.csv")
df_user_metadata
# Out:
#      user_id  age    gender  height_m  weight_kg experience_level  \
# 0      U0001   47      Male      1.72       75.8         Advanced
# 1      U0002   34   Female       1.42       78.7         Advanced
# 2      U0003   40      Male      1.71       75.2         Advanced
# 3      U0004   23    Female      1.98       83.1        Beginner
# 4      U0005   39      Male      1.49       78.1         Advanced
# ...      ...  ...       ...       ...        ...              ...
# 1231   U0894   50      Male      1.83       72.8         Beginner
# 1232   U0693   44      Male      1.66        NaN         Beginner
# 1233   U0728   19      Male      1.84       84.0         Beginner
# 1234   U0363   31         F      1.89       49.1         Beginner
# 1235   U0597   41    Female      1.82       96.6        Beginner
#
#       workout_frequency_days_week  fat_percentage
# 0                               2            21.3
# 1                               5            20.0
# ...

# %%
df_workout_session = pd.read_csv("../data/raw/workout_sessions_messy.csv")
df_workout_session
# Out:
#         user_id        date     exercise  sets  reps  weight_kg  \
# 0         U1186  2024-01-25      cycling   NaN   NaN        NaN
# 1         U0316  2024-01-16  Bench Press   3.0   5.0        NaN
# 2         U0614  2024-08-03      Cycling   NaN   NaN        NaN
# 3        U0355   2024-10-26        Squat   4.0   5.0        NaN
# 4         U0780  2024-07-02       Rowing   NaN   NaN        NaN
# ...         ...         ...          ...   ...   ...        ...
# 153745    U0896  2024-08-17      Running   NaN   NaN        NaN
# 153746    U1043  2024-02-05        Squat   3.0   5.0       83.3
# 153747    U0499  2024-10-06      Cycling   NaN   NaN        NaN
# 153748    U0103  2024-11-14       Rowing   NaN   NaN        NaN
# 153749    U0375  2024-05-15      Running   NaN   NaN        NaN
#
#         session_duration_hr  calories_burned  avg_bpm  max_bpm  \
# 0                       NaN            198.0    156.0      176
# 1                      0.56            235.0     90.0      112
# ...
